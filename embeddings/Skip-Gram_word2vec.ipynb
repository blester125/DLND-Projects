# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
from collections import Counter
threshold = 1e-5
word_counts = Counter(int_words)
total_words = len(int_words)
#freqs = {word: word_counts[word] / total_words for word in int_words}
freqs = {word: count / total_words for word, count in word_counts.items()}
probs = {word: 1 - np.sqrt(threshold / freqs[word]) for word in int_words}
train_words = [word for word in int_words if probs[word] < np.random.uniform()]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(low=1, high=window_size+1)
    start = max(0, idx - R)
    stop = min(idx + R + 1, len(words))
    targets = set(words[start:idx] + words[idx+1:stop])
    
    return list(targets)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=[None])
    labels = tf.placeholder(tf.int32, shape=[None, None])

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 300 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.get_variable(
        "EmbeddingMatrix", 
        shape=[n_vocab, n_embedding], 
        initializer=tf.random_uniform_initializer(-1., 1.)
    )# create embedding weight matrix here
    with tf.device("/cpu:0"):
        embed = tf.nn.embedding_lookup(embedding, inputs)# use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.get_variable(
        "softmax_weights",
        shape=[n_vocab, n_embedding],
        initializer=tf.truncated_normal_initializer(stddev=0.1)
    )# create softmax weight matrix here
    softmax_b = tf.get_variable(
        "softmax_biases",
        shape=[n_vocab],
        initializer=tf.constant_initializer(0.0)
    )# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(
        softmax_w,
        softmax_b,
        labels,
        embed,
        n_sampled,
        n_vocab
    ) 
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
import random
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100), end="\r")
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Nearest to five: borrowing, koster, places, progressed, breads, cocaine, geopolitics, hc,
# Nearest to united: usefully, multiparty, metre, operatic, paratroopers, glidrose, knocking, yount,
# Nearest to known: marques, southwards, housed, piercings, tang, err, flanagan, fort,
# Nearest to up: disenchanted, shimla, toves, meandering, helping, antiprotons, financiers, msi,
# Nearest to but: goalie, collectively, childs, niosh, paxman, quadriceps, sydney, photoelectric,
# Nearest to were: pistols, alioth, apennines, magazines, prized, alcan, gays, trips,
# Nearest to history: pride, unplugged, liaison, eunuchs, soften, exploring, eminent, euhemerus,
# Nearest to other: genres, intolerance, geography, wakayama, melcher, assess, lightning, slough,
# Nearest to police: eritrea, ryswick, purer, stipulation, reggio, colonia, visigothic, out,
# Nearest to joseph: nozzles, metallized, bellied, yah, symmetry, prasad, coffey, theologies,
# Nearest to alternative: polypeptides, cksburg, merck, satrap, decent, milarepa, craft, buzan,
# Nearest to engineering: densities, europa, rattle, continued, belshazzar, synonymous, unsurpassed, civilized,
# Nearest to magazine: bulgars, segmentation, interrogators, pungent, vegas, ticketing, pakistan, bernstein,
# Nearest to additional: electropositive, intercollegiate, pane, completion, shelby, newcomen, lites, dpi,
# Nearest to ice: user, leukemia, digital, chydenius, kbyte, downer, vicki, evades,
# Nearest to writers: abdicated, dilution, mamie, grabbing, beggar, whammy, aegis, crowded,
# Nearest to five: borrowing, cocaine, places, breads, pony, koster, geopolitics, cowl,
# Nearest to united: usefully, metre, multiparty, operatic, manipulates, register, eminent, teaches,
# Nearest to known: housed, marques, piercings, fort, past, southwards, tang, fiercely,
# Nearest to up: disenchanted, helping, meandering, waters, formation, serves, either, shimla,
# Nearest to but: goalie, collectively, sydney, interim, over, niosh, paxman, israel,
# Nearest to were: magazines, pistols, massive, attempted, alioth, trips, prized, gays,
# Nearest to history: pride, eminent, derived, facility, scientists, unplugged, exploring, britain,
# Nearest to other: genres, geography, promoted, serving, intuitively, assess, overall, intolerance,
# Nearest to police: eritrea, out, purer, ryswick, adds, visigothic, colonia, baywatch,
# Nearest to joseph: nozzles, metallized, bellied, misuse, symmetry, coffey, tiamat, mil,
# Nearest to alternative: polypeptides, cksburg, decent, craft, viii, fc, satrap, merck,
# Nearest to engineering: europa, densities, continued, frequency, synonymous, rattle, belshazzar, modeling,
# Nearest to magazine: bulgars, interrogators, segmentation, storm, pungent, pakistan, bernstein, vegas,
# Nearest to additional: through, electropositive, intercollegiate, completion, pane, shelby, indicate, rotor,
# Nearest to ice: user, digital, leukemia, chydenius, kbyte, marcus, vicki, encouraging,
# Nearest to writers: dilution, abdicated, beggar, aegis, give, grabbing, mamie, embankments,
# Nearest to five: borrowing, geopolitics, pony, cocaine, manufacturer, gchq, hc, koster,
# Nearest to united: usefully, multiparty, metre, knocking, eminent, constituencies, manipulates, alphabet,
# Nearest to known: housed, marques, tang, southwards, piercings, strictest, fort, past,
# Nearest to up: disenchanted, shimla, helping, meandering, waters, mythological, communicated, laments,
# Nearest to but: goalie, collectively, sydney, interim, childs, quadriceps, conquering, quotations,
# Nearest to were: massive, pistols, magazines, trips, alioth, apennines, attempted, prized,
# Nearest to history: pride, eminent, exploring, liaison, facility, unplugged, scientists, malls,
# Nearest to other: genres, promoted, geography, goidelic, intuitively, intolerance, slough, slave,
# Nearest to police: eritrea, purer, out, visigothic, ryswick, reggio, colonia, stipulation,
# Nearest to joseph: nozzles, misuse, symmetry, mil, metallized, coffey, bellied, theologies,
# Nearest to alternative: polypeptides, cksburg, craft, decent, merck, fc, fluently, pump,
# Nearest to engineering: europa, densities, continued, synonymous, frequency, rattle, modeling, belshazzar,
# Nearest to magazine: bulgars, interrogators, vegas, pungent, segmentation, storm, bernstein, pakistan,
# Nearest to additional: electropositive, completion, through, intercollegiate, pane, indicate, shelby, orchestra,
# Nearest to ice: user, digital, leukemia, chydenius, encouraging, kbyte, downer, dual,
# Nearest to writers: dilution, abdicated, aegis, beggar, give, grabbing, mamie, twilight,
# Nearest to five: geopolitics, borrowing, zero, pony, hc, six, gchq, manufacturer,
# Nearest to united: multiparty, usefully, constituencies, metre, knocking, dachshunds, paratroopers, bolivar,
# Nearest to known: tang, housed, marques, fort, southwards, err, strictest, piercings,
# Nearest to up: disenchanted, shimla, helping, meandering, financiers, laments, communicated, waters,
# Nearest to but: goalie, collectively, childs, interim, niosh, staunchest, photoelectric, conquering,
# Nearest to were: massive, magazines, apennines, pistols, attempted, alioth, prized, trips,
# Nearest to history: pride, eminent, exploring, unplugged, liaison, malls, euhemerus, mauritius,
# Nearest to other: genres, thrift, goidelic, promoted, nicea, slough, intolerance, intuitively,
# Nearest to police: eritrea, colonia, ryswick, reggio, out, lonesome, stipulation, purer,
# Nearest to joseph: nozzles, mil, archbishop, bellied, simon, perseus, garland, mej,
# Nearest to alternative: polypeptides, cksburg, craft, decent, satrap, merck, pump, fc,
# Nearest to engineering: densities, europa, continued, synonymous, rattle, frequency, civilized, belshazzar,
# Nearest to magazine: interrogators, pungent, bulgars, vegas, segmentation, bernstein, ticketing, schoolgirl,
# Nearest to additional: electropositive, completion, intercollegiate, pane, through, indicate, dpi, rotor,
# Nearest to ice: user, digital, leukemia, chydenius, downer, kbyte, lydon, encouraging,
# Nearest to writers: dilution, abdicated, aegis, grabbing, beggar, twilight, mamie, seminumerical,
# Nearest to five: geopolitics, six, borrowing, gchq, koster, zero, hc, pony,
# Nearest to united: multiparty, usefully, constituencies, metre, dachshunds, knocking, paratroopers, deputy,
# Nearest to known: marques, housed, err, southwards, tang, fort, piercings, ame,
# Nearest to up: disenchanted, shimla, helping, laments, meandering, waters, financiers, antiprotons,
# Nearest to but: goalie, collectively, childs, quadriceps, niosh, risky, interim, alligators,
# Nearest to were: massive, magazines, attempted, apennines, tra, pistols, alioth, renown,
# Nearest to history: pride, eminent, exploring, unplugged, malls, luisa, veterans, liaison,
# Nearest to other: genres, thrift, smo, nicea, intolerance, afterword, slough, goidelic,
# Nearest to police: eritrea, colonia, ryswick, reggio, lonesome, out, stipulation, joliet,
# Nearest to joseph: nozzles, archbishop, simon, garland, mil, schweitzer, metrorail, mej,
# Nearest to alternative: polypeptides, cksburg, craft, merck, pump, decent, buzan, fc,
# Nearest to engineering: densities, europa, synonymous, civilized, rattle, continued, silicone, modeling,
# Nearest to magazine: pungent, vegas, segmentation, interrogators, bernstein, bulgars, ticketing, schoolgirl,
# Nearest to additional: electropositive, completion, intercollegiate, through, pane, indicate, dpi, sravaka,
# Nearest to ice: user, leukemia, digital, chydenius, downer, lydon, kbyte, encouraging,
# Nearest to writers: dilution, abdicated, grabbing, bobby, beggar, aegis, twilight, vampyre,
# Nearest to five: zero, geopolitics, households, total, six, borrowing, pony, koster,
# Nearest to united: multiparty, usefully, constituencies, metre, bolivar, dachshunds, gubernatorial, paratroopers,
# Nearest to known: err, marques, tang, housed, ame, piercings, southwards, reclassification,
# Nearest to up: disenchanted, shimla, shinai, waters, fuse, armor, laments, mythological,
# Nearest to but: goalie, quadriceps, childs, collectively, niosh, religiously, risky, tomita,
# Nearest to were: massive, attempted, apennines, pistols, magazines, tra, renown, alioth,
# Nearest to history: pride, eminent, exploring, malls, euhemerus, unplugged, facility, veterans,
# Nearest to other: afterword, genres, nicea, overall, smo, intuitively, thrift, sobriquet,
# Nearest to police: eritrea, colonia, ryswick, reggio, lonesome, out, stipulation, joliet,
# Nearest to joseph: nozzles, simon, archbishop, garland, mil, theologies, tiamat, perseus,
# Nearest to alternative: polypeptides, cksburg, merck, craft, satrap, buzan, milarepa, pump,
# Nearest to engineering: densities, europa, modeling, synonymous, civilized, continued, rattle, frequency,
# Nearest to magazine: pungent, vegas, segmentation, interrogators, bernstein, schoolgirl, ticketing, bulgars,
# Nearest to additional: electropositive, through, completion, pane, intercollegiate, dpi, sravaka, indicate,
# Nearest to ice: user, leukemia, chydenius, digital, downer, lydon, kbyte, dual,
# Nearest to writers: dilution, grabbing, abdicated, aegis, vampyre, bobby, juliet, beggar,
# Nearest to five: geopolitics, zero, six, households, pony, koster, gchq, palo,
# Nearest to united: multiparty, constituencies, usefully, paratroopers, deputy, gubernatorial, bolivar, metre,
# Nearest to known: tang, marques, err, housed, ame, reclassification, southwards, piercings,
# Nearest to up: disenchanted, shinai, shimla, laments, waters, meandering, mythological, armor,
# Nearest to but: goalie, quadriceps, collectively, childs, risky, niosh, enlist, tomita,
# Nearest to were: massive, pistols, magazines, apennines, attempted, tra, alioth, trips,
# Nearest to history: pride, exploring, malls, euhemerus, eminent, liaison, unplugged, ants,
# Nearest to other: overall, genres, melcher, smo, sobriquet, thrift, aswan, nicea,
# Nearest to police: eritrea, colonia, ryswick, lonesome, reggio, out, joliet, macquarie,
# Nearest to joseph: nozzles, simon, archbishop, theologies, mil, garland, coffey, couture,
# Nearest to alternative: polypeptides, cksburg, merck, craft, satrap, milarepa, pump, decent,
# Nearest to engineering: densities, europa, modeling, silicone, continued, synonymous, rattle, frequency,
# Nearest to magazine: vegas, pungent, interrogators, segmentation, bernstein, schoolgirl, micrograms, programmes,
# Nearest to additional: electropositive, pane, through, completion, dpi, sravaka, intercollegiate, maintainers,
# Nearest to ice: leukemia, user, chydenius, downer, kbyte, lydon, vx, dual,
# Nearest to writers: dilution, grabbing, poets, vampyre, abdicated, bobby, aegis, additions,
# Nearest to five: six, zero, households, geopolitics, total, citizenry, gchq, two,
# Nearest to united: multiparty, usefully, constituencies, woolsack, paratroopers, deputy, metre, gubernatorial,
# Nearest to known: tang, reclassification, housed, err, marques, ame, piercings, pundit,
# Nearest to up: disenchanted, shinai, laments, shimla, mythological, waters, ssi, meandering,
# Nearest to but: quadriceps, collectively, goalie, niosh, schacht, childs, risky, religiously,
# Nearest to were: massive, attempted, apennines, tra, pistols, alioth, until, gays,
# Nearest to history: pride, exploring, malls, euhemerus, liaison, eminent, veterans, article,
# Nearest to other: kontor, overall, genres, sobriquet, yassin, aswan, amistad, afterword,
# Nearest to police: eritrea, lonesome, colonia, ryswick, joliet, out, reggio, macquarie,
# Nearest to joseph: nozzles, theologies, simon, perseus, couture, coffey, archbishop, botanist,
# Nearest to alternative: polypeptides, merck, cksburg, satrap, pump, craft, buzan, decent,
# Nearest to engineering: europa, densities, modeling, continued, silicone, synonymous, rattle, sensitive,
# Nearest to magazine: vegas, interrogators, segmentation, pungent, bernstein, ticketing, vih, schoolgirl,
# Nearest to additional: electropositive, completion, through, sravaka, dpi, pane, intercollegiate, newcomen,
# Nearest to ice: leukemia, user, lydon, chydenius, downer, liquid, vx, kbyte,
# Nearest to writers: poets, grabbing, dilution, vampyre, literary, aegis, abdicated, beggar,
# Nearest to five: zero, six, seven, households, geopolitics, two, four, gchq,
# Nearest to united: multiparty, paratroopers, dachshunds, usefully, metre, woolsack, deputy, toured,
# Nearest to known: tang, reclassification, err, housed, marques, msf, ame, observer,
# Nearest to up: disenchanted, laments, shimla, shinai, ssi, antiprotons, videotape, mythological,
# Nearest to but: quadriceps, goalie, collectively, niosh, childs, tomita, religiously, washers,
# Nearest to were: massive, apennines, attempted, pistols, datagrams, alioth, magazines, until,
# Nearest to history: pride, malls, exploring, liaison, euhemerus, eminent, goa, mauritius,
# Nearest to other: kontor, overall, smo, backbones, afterword, aswan, yassin, crude,
# Nearest to police: eritrea, lonesome, out, joliet, colonia, ryswick, macquarie, reggio,
# Nearest to joseph: simon, theologies, perseus, nozzles, coffey, garland, couture, botanist,
# Nearest to alternative: polypeptides, cksburg, merck, satrap, craft, pump, buzan, decent,
# Nearest to engineering: densities, europa, modeling, continued, silicone, banking, sciences, rattle,
# Nearest to magazine: vegas, bernstein, interrogators, segmentation, schoolgirl, pungent, ticketing, busters,
# Nearest to additional: electropositive, completion, through, pane, sravaka, dpi, newcomen, lacked,
# Nearest to ice: leukemia, user, lydon, foot, liquid, kbyte, vx, olympics,
# Nearest to writers: poets, grabbing, vampyre, dilution, literary, pazzi, busby, beggar,
# Nearest to five: zero, six, two, households, geopolitics, four, total, seven,
# Nearest to united: multiparty, metre, usefully, paratroopers, dachshunds, gubernatorial, toured, woolsack,
# Nearest to known: tang, reclassification, housed, ibf, msf, marques, piercings, err,
# Nearest to up: disenchanted, laments, antiprotons, shinai, ssi, obstacle, shimla, vilayet,
# Nearest to but: quadriceps, goalie, collectively, tomita, niosh, childs, applying, enlist,
# Nearest to were: apennines, massive, pistols, attempted, datagrams, until, tra, alioth,
# Nearest to history: pride, malls, exploring, goa, liaison, eminent, article, org,
# Nearest to other: kontor, overall, cultivating, genres, almonds, melcher, afterword, smo,
# Nearest to police: eritrea, lonesome, joliet, out, ryswick, macquarie, reggio, respondents,
# Nearest to joseph: simon, theologies, nozzles, coffey, hypothesis, garland, perseus, couture,
# Nearest to alternative: polypeptides, merck, cksburg, craft, satrap, pump, buzan, fontvieille,
# Nearest to engineering: densities, europa, continued, modeling, silicone, banking, sciences, tuning,
# Nearest to magazine: vegas, bernstein, segmentation, interrogators, schoolgirl, busters, heard, ticketing,
# Nearest to additional: pane, electropositive, completion, through, sravaka, dpi, newcomen, maintainers,
# Nearest to ice: user, leukemia, lydon, olympics, foot, chydenius, honshu, kbyte,
# Nearest to writers: poets, vampyre, grabbing, dilution, pazzi, seminumerical, abdicated, streamlined,
# Nearest to five: zero, six, two, four, households, seven, total, pony,h
# Nearest to united: usefully, metre, woolsack, multiparty, glidrose, gubernatorial, paratroopers, factual,
# Nearest to known: housed, tang, reclassification, err, petal, stills, carom, strictest,
# Nearest to up: disenchanted, shinai, shimla, laments, dagome, ssi, financiers, obstacle,
# Nearest to but: quadriceps, goalie, tomita, collectively, photoelectric, childs, enlist, niosh,
# Nearest to were: pistols, massive, apennines, datagrams, attempted, until, magazines, alioth,
# Nearest to history: pride, malls, exploring, eminent, org, allie, description, goa,
# Nearest to other: genres, kontor, almonds, melcher, as, smo, overall, oresund,
# Nearest to police: joliet, lonesome, eritrea, macquarie, ryswick, out, reggio, respondents,
# Nearest to joseph: theologies, nozzles, hypothesis, bellied, simon, perseus, symmetry, couture,
# Nearest to alternative: polypeptides, merck, cksburg, craft, satrap, buzan, pump, milarepa,
# Nearest to engineering: densities, europa, modeling, continued, silicone, sciences, academic, anthropology,
# Nearest to magazine: vegas, segmentation, programmes, bernstein, interrogators, hulk, corporation, database,
# Nearest to additional: dpi, pane, electropositive, completion, sravaka, through, maintainers, manoeuvres,
# Nearest to ice: leukemia, user, lydon, olympics, vx, liquid, kbyte, foot,
# Nearest to writers: poets, vampyre, pazzi, literary, grabbing, additions, megillat, seminumerical,
# Nearest to five: zero, six, two, four, one, seven, households, eight,ch
# Nearest to united: metre, usefully, woolsack, glidrose, gubernatorial, multiparty, toured, paratroopers,
# Nearest to known: reclassification, tang, ame, housed, petal, piercings, msf, ibf,
# Nearest to up: disenchanted, piccolo, shinai, burgers, madrid, antiprotons, shimla, ewart,
# Nearest to but: quadriceps, collectively, awestruck, goalie, photoelectric, enlist, tomita, applying,
# Nearest to were: apennines, massive, pistols, until, datagrams, escorts, attempted, magazines,
# Nearest to history: pride, malls, exploring, allie, org, eminent, liaison, goa,
# Nearest to other: genres, kontor, as, smo, sobriquet, shadows, overall, almonds,
# Nearest to police: eritrea, joliet, ryswick, out, reggio, lonesome, macquarie, respondents,
# Nearest to joseph: theologies, hypothesis, perseus, nozzles, bellied, simon, couture, prasad,
# Nearest to alternative: polypeptides, merck, cksburg, craft, pump, satrap, buzan, milarepa,
# Nearest to engineering: europa, modeling, densities, continued, silicone, sciences, anthropology, academic,
# Nearest to magazine: vegas, segmentation, corporation, pungent, programmes, corp, interview, morita,
# Nearest to additional: pane, electropositive, sravaka, dpi, completion, through, manoeuvres, lox,
# Nearest to ice: leukemia, user, olympics, lydon, foot, vx, liquid, honshu,
# Nearest to writers: poets, vampyre, pazzi, literary, dilution, additions, grabbing, megillat,
# Nearest to five: zero, six, four, one, two, seven, eight, three,c/batch
# Nearest to united: toured, metre, gubernatorial, glidrose, paratroopers, dachshunds, bolivar, kingdom,
# Nearest to known: msf, tang, ibf, reclassification, stills, ame, mars, bu,
# Nearest to up: disenchanted, dagome, madrid, ewart, shinai, antiprotons, burgers, obstacle,
# Nearest to but: quadriceps, awestruck, enlist, collectively, sdlp, risky, goalie, because,
# Nearest to were: massive, attempted, apennines, datagrams, until, escorts, pistols, magazines,
# Nearest to history: pride, malls, exploring, goa, allie, eminent, liaison, org,
# Nearest to other: genres, kontor, jen, predominantly, smo, sobriquet, darwinism, oresund,
# Nearest to police: joliet, out, ryswick, eritrea, lonesome, macquarie, reggio, aerial,
# Nearest to joseph: theologies, hypothesis, bellied, ladislaus, simon, perseus, couture, nozzles,
# Nearest to alternative: polypeptides, merck, cksburg, satrap, craft, buzan, pump, fontvieille,
# Nearest to engineering: europa, modeling, densities, continued, silicone, sciences, anthropology, demonstrator,
# Nearest to magazine: vegas, bernstein, busters, heard, interrogators, segmentation, methodological, erd,
# Nearest to additional: pane, completion, sravaka, dpi, electropositive, through, ashkenazim, manoeuvres,
# Nearest to ice: leukemia, user, olympics, lydon, foot, vx, liquid, downer,
# Nearest to writers: poets, vampyre, pazzi, literary, novelists, grabbing, additions, megillat,
# Nearest to five: zero, six, four, two, one, seven, eight, three,c/batch
# Nearest to united: metre, toured, glidrose, usefully, gubernatorial, kingdom, woolsack, factual,
# Nearest to known: ibf, tang, venn, mars, bu, housed, carom, stills,
# Nearest to up: disenchanted, madrid, shinai, obstacle, dagome, deco, antiprotons, senators,
# Nearest to but: quadriceps, risky, awestruck, collectively, enlist, photoelectric, comedy, goalie,
# Nearest to were: apennines, massive, attempted, until, escorts, datagrams, mammalogy, pistols,
# Nearest to history: pride, malls, goa, exploring, allie, article, eminent, notoc,
# Nearest to other: genres, kontor, oresund, as, shadows, darwinism, jen, overall,
# Nearest to police: out, joliet, ryswick, lonesome, macquarie, eritrea, reggio, hanjour,
# Nearest to joseph: theologies, ladislaus, hypothesis, simon, polymath, nozzles, bellied, pissarro,
# Nearest to alternative: polypeptides, merck, cksburg, craft, pump, buzan, fontvieille, satrap,
# Nearest to engineering: modeling, continued, europa, densities, silicone, sciences, anthropology, tuning,
# Nearest to magazine: vegas, segmentation, bernstein, morita, heard, methodological, corporation, erd,
# Nearest to additional: completion, pane, dpi, sravaka, electropositive, through, ashkenazim, indicate,
# Nearest to ice: leukemia, user, lydon, olympics, beneath, downer, vx, foot,
# Nearest to writers: poets, vampyre, pazzi, novelists, literary, dilution, additions, streamlined,
# Nearest to five: zero, six, four, two, one, seven, eight, three,c/batch
# Nearest to united: metre, usefully, kingdom, factual, glidrose, toured, woolsack, knocking,
# Nearest to known: ibf, bu, petal, ame, ontario, tang, reclassification, mars,
# Nearest to up: disenchanted, obstacle, shinai, antiprotons, ewart, burgers, madrid, dagome,
# Nearest to but: quadriceps, risky, awestruck, applying, collectively, enlist, niosh, tomita,
# Nearest to were: massive, apennines, attempted, pistols, datagrams, until, escorts, magazines,
# Nearest to history: pride, malls, goa, exploring, allie, eminent, org, tetris,
# Nearest to other: as, oresund, genres, kontor, predominantly, darwinism, almonds, smo,
# Nearest to police: lonesome, joliet, ryswick, macquarie, out, eritrea, reggio, hanjour,
# Nearest to joseph: theologies, hypothesis, bellied, facets, polymath, ladislaus, pissarro, simon,
# Nearest to alternative: polypeptides, merck, cksburg, craft, buzan, fontvieille, satrap, milarepa,
# Nearest to engineering: modeling, continued, europa, densities, silicone, anthropology, facilities, sciences,
# Nearest to magazine: vegas, segmentation, busters, bernstein, morita, erd, corporation, heard,
# Nearest to additional: pane, completion, dpi, sravaka, through, electropositive, indicate, ashkenazim,
# Nearest to ice: leukemia, user, olympics, lydon, exterminating, devastates, liquid, foot,
# Nearest to writers: poets, vampyre, pazzi, literary, novelists, additions, megillat, actors,
# Nearest to five: zero, six, four, two, one, seven, eight, three,c/batch
# Nearest to united: metre, subtitled, kingdom, toured, factual, glidrose, usefully, knocking,
# Nearest to known: ibf, bu, mars, istat, ame, petal, ontario, stills,
# Nearest to up: disenchanted, ewart, shinai, deco, mcclintock, burgers, obstacle, dagome,
# Nearest to but: risky, quadriceps, enlist, niosh, applying, collectively, absence, comedy,
# Nearest to were: datagrams, apennines, pistols, escorts, attempted, massive, magazines, until,
# Nearest to history: pride, malls, goa, allie, exploring, tetris, org, article,
# Nearest to other: darwinism, as, genres, are, bulletproof, oresund, predominantly, kontor,
# Nearest to police: joliet, lonesome, macquarie, out, ryswick, reggio, hanjour, eritrea,
# Nearest to joseph: theologies, facets, hypothesis, bellied, polymath, ladislaus, mej, pissarro,
# Nearest to alternative: polypeptides, merck, cksburg, craft, buzan, fontvieille, pump, milarepa,
# Nearest to engineering: modeling, continued, europa, densities, sciences, silicone, facilities, anthropology,
# Nearest to magazine: vegas, segmentation, methodological, busters, morita, bernstein, programmes, interrogators,
# Nearest to additional: pane, completion, dpi, sravaka, indicate, ashkenazim, electropositive, through,
# Nearest to ice: user, leukemia, olympics, lydon, downer, exterminating, liquid, corvo,
# Nearest to writers: poets, vampyre, novelists, literary, pazzi, actors, additions, dilution,
# Nearest to five: zero, six, two, one, four, seven, eight, three,c/batch
# Nearest to united: metre, kingdom, toured, subtitled, glidrose, certiorari, gubernatorial, factual,
# Nearest to known: ibf, bu, ame, mars, istat, housed, stills, timescale,
# Nearest to up: disenchanted, shinai, ewart, obstacle, burgers, dagome, mcclintock, deco,
# Nearest to but: enlist, collectively, the, quadriceps, applying, risky, because, of,
# Nearest to were: apennines, attempted, escorts, until, datagrams, massive, now, pistols,
# Nearest to history: pride, goa, malls, exploring, article, allie, notoc, org,
# Nearest to other: as, predominantly, oresund, are, darwinism, from, genres, smo,
# Nearest to police: joliet, macquarie, lonesome, out, reggio, eritrea, ryswick, hanjour,
# Nearest to joseph: theologies, hypothesis, polymath, facets, ladislaus, bellied, tanach, socioeconomics,
# Nearest to alternative: polypeptides, merck, cksburg, buzan, craft, pump, fontvieille, divert,
# Nearest to engineering: modeling, europa, continued, densities, sciences, silicone, anthropology, pharmacology,
# Nearest to magazine: segmentation, vegas, morita, methodological, busters, greencine, dada, corporation,
# Nearest to additional: pane, completion, indicate, ashkenazim, sravaka, electropositive, eg, holocene,
# Nearest to ice: leukemia, user, olympics, lydon, downer, beneath, exterminating, corvo,
# Nearest to writers: poets, vampyre, novelists, literary, pazzi, dilution, actors, essayists,
# Nearest to five: six, zero, two, four, one, seven, eight, nine,ec/batch
# Nearest to united: toured, metre, kingdom, subtitled, knocking, certiorari, affirmative, speculating,
# Nearest to known: ibf, bu, housed, istat, strictest, tang, ontario, reclassification,
# Nearest to up: disenchanted, burgers, shinai, dagome, mcclintock, obstacle, ewart, antiprotons,
# Nearest to but: risky, enlist, applying, collectively, tver, quadriceps, photoelectric, because,
# Nearest to were: apennines, datagrams, attempted, massive, escorts, until, pistols, magazines,
# Nearest to history: pride, goa, allie, malls, org, notoc, exploring, biographies,
# Nearest to other: are, feedstock, as, predominantly, oresund, from, darwinism, backbones,
# Nearest to police: joliet, out, macquarie, reggio, lonesome, ryswick, eritrea, hanjour,
# Nearest to joseph: polymath, theologies, facets, ladislaus, hypothesis, tanach, bellied, mej,
# Nearest to alternative: polypeptides, cksburg, merck, buzan, craft, fontvieille, pump, satrap,
# Nearest to engineering: modeling, continued, europa, silicone, densities, anthropology, sciences, demonstrator,
# Nearest to magazine: vegas, segmentation, methodological, morita, dada, greencine, busters, interrogators,
# Nearest to additional: completion, pane, ashkenazim, swordsmith, indicate, sravaka, eg, dpi,
# Nearest to ice: user, leukemia, lydon, olympics, downer, corvo, exterminating, devastates,
# Nearest to writers: poets, vampyre, novelists, pazzi, actors, essayists, literary, dilution,
# Nearest to five: six, zero, one, two, four, seven, eight, nine,ec/batch
# Nearest to united: metre, toured, kingdom, subtitled, knocking, sabine, thionyl, glidrose,
# Nearest to known: ibf, bu, ontario, miller, istat, tang, housed, petal,
# Nearest to up: disenchanted, obstacle, shinai, antiprotons, dagome, ewart, madrid, mcclintock,
# Nearest to but: tver, risky, collectively, heed, applying, enlist, niosh, cai,
# Nearest to were: apennines, datagrams, attempted, until, magazines, now, escorts, pistols,
# Nearest to history: pride, goa, malls, detailed, boardgamegeek, allie, article, org,
# Nearest to other: predominantly, as, from, are, smo, kontor, miasto, darwinism,
# Nearest to police: joliet, lonesome, macquarie, out, hanjour, bayard, ryswick, reggio,
# Nearest to joseph: polymath, theologies, facets, hypothesis, ladislaus, couture, mej, botanist,
# Nearest to alternative: polypeptides, merck, cksburg, buzan, pump, craft, milarepa, alliterative,
# Nearest to engineering: continued, europa, modeling, silicone, densities, anthropology, sciences, pharmacology,
# Nearest to magazine: vegas, segmentation, morita, spassky, poststructuralist, busters, bernstein, dada,
# Nearest to additional: completion, pane, indicate, ashkenazim, swordsmith, sravaka, dpi, canoe,
# Nearest to ice: user, leukemia, lydon, olympics, corvo, downer, devastates, exterminating,
# Nearest to writers: poets, vampyre, novelists, pazzi, literary, essayists, dilution, novel,
# Nearest to five: zero, six, one, two, four, seven, eight, nine,ec/batch
# Nearest to united: kingdom, metre, subtitled, toured, sabine, luce, thionyl, factual,
# Nearest to known: ibf, ontario, timescale, tang, istat, miller, petal, housed,
# Nearest to up: disenchanted, dagome, antiprotons, obstacle, shinai, burgers, ewart, madrid,
# Nearest to but: risky, applying, collectively, their, sums, enlist, the, niosh,
# Nearest to were: apennines, datagrams, attempted, magazines, now, escorts, pistols, until,
# Nearest to history: pride, malls, goa, notoc, org, shown, allie, description,
# Nearest to other: are, as, of, from, predominantly, and, oresund, such,
# Nearest to police: joliet, macquarie, lonesome, hanjour, bayard, ryswick, out, eritrea,
# Nearest to joseph: polymath, theologies, facets, homily, tanach, hypothesis, kircher, yangon,
# Nearest to alternative: polypeptides, cksburg, merck, buzan, craft, milarepa, fontvieille, satrap,
# Nearest to engineering: continued, europa, modeling, densities, silicone, anthropology, demonstrator, facilities,
# Nearest to magazine: vegas, segmentation, morita, methodological, masterpiece, busters, whitechapel, ici,
# Nearest to additional: completion, pane, ashkenazim, indicate, eg, swordsmith, searle, holocene,
# Nearest to ice: user, leukemia, lydon, tab, olympics, corvo, liquid, volleyball,
# Nearest to writers: poets, vampyre, novelists, pazzi, literary, essayists, dilution, actors,
# Nearest to five: six, zero, one, two, four, seven, eight, nine,ec/batch
# Nearest to united: kingdom, subtitled, metre, toured, luce, sabine, states, choate,
# Nearest to known: ibf, bu, ontario, petal, miller, algorism, istat, tang,
# Nearest to up: disenchanted, dagome, burgers, ewart, obstacle, shinai, boys, madrid,
# Nearest to but: risky, tver, comedy, their, enlist, collectively, cai, sums,
# Nearest to were: datagrams, apennines, pistols, magazines, now, attempted, escorts, until,
# Nearest to history: pride, goa, shown, ethnomusicology, notoc, article, org, malls,
# Nearest to other: are, from, as, and, of, predominantly, grand, smo,
# Nearest to police: joliet, out, lonesome, hanjour, macquarie, reggio, guard, condiments,
# Nearest to joseph: polymath, theologies, referred, yangon, facets, tanach, rgya, botanist,
# Nearest to alternative: polypeptides, cksburg, merck, buzan, milarepa, craft, fontvieille, pump,
# Nearest to engineering: modeling, europa, silicone, continued, densities, pharmacology, tuning, demonstrator,
# Nearest to magazine: vegas, masterpiece, methodological, morita, mammalian, interview, segmentation, busters,
# Nearest to additional: pane, completion, ashkenazim, holocene, searle, swordsmith, eg, gunther,
# Nearest to ice: user, leukemia, tab, lydon, exterminating, corvo, downer, olympics,
# Nearest to writers: poets, novelists, vampyre, essayists, pazzi, dilution, literary, fiction,
# Nearest to five: six, zero, one, two, four, seven, eight, nine,ec/batch
# Nearest to united: kingdom, metre, toured, luce, subtitled, states, certiorari, choate,
# Nearest to known: ibf, ontario, timescale, algorism, bu, tang, istat, petal,
# Nearest to up: disenchanted, burgers, dagome, obstacle, mythological, antiprotons, shinai, ewart,
# Nearest to but: their, the, because, risky, collectively, sums, applying, tver,
# Nearest to were: datagrams, now, until, attempted, massive, apennines, escorts, magazines,
# Nearest to history: pride, goa, notoc, article, ethnomusicology, detailed, malls, org,
# Nearest to other: are, from, predominantly, and, of, smo, oresund, christiern,
# Nearest to police: joliet, out, guard, condiments, lonesome, macquarie, hanjour, constabulary,
# Nearest to joseph: polymath, yangon, theologies, facets, handbuch, referred, homily, ladislaus,
# Nearest to alternative: cksburg, merck, polypeptides, buzan, milarepa, alliterative, fontvieille, craft,
# Nearest to engineering: europa, modeling, continued, silicone, demonstrator, tuning, densities, pharmacology,
# Nearest to magazine: methodological, masterpiece, vegas, ici, segmentation, spassky, morita, mammalian,
# Nearest to additional: completion, ashkenazim, holocene, pane, searle, swordsmith, indicate, eg,
# Nearest to ice: user, leukemia, lydon, downer, exterminating, olympics, tab, encouraging,
# Nearest to writers: poets, vampyre, novelists, essayists, fiction, pazzi, americans, dilution,
# Nearest to five: six, zero, one, four, two, seven, eight, nine,ec/batch
# Nearest to united: kingdom, metre, luce, toured, subtitled, states, speculating, choate,
# Nearest to known: ibf, tang, bu, ontario, istat, timescale, miller, reclassification,
# Nearest to up: disenchanted, burgers, dagome, ewart, obstacle, shinai, gestation, mcclintock,
# Nearest to but: risky, tver, collectively, their, because, enlist, applying, comedy,
# Nearest to were: datagrams, until, attempted, now, massive, apennines, pistols, escorts,
# Nearest to history: pride, notoc, goa, article, ethnomusicology, shown, detailed, malls,
# Nearest to other: are, oresund, predominantly, and, from, smo, cultivating, notably,
# Nearest to police: out, joliet, guard, condiments, lonesome, hanjour, macquarie, uniformed,
# Nearest to joseph: polymath, mej, handbuch, ladislaus, facets, kircher, referred, rgya,
# Nearest to alternative: cksburg, polypeptides, merck, buzan, milarepa, pump, alliterative, fontvieille,
# Nearest to engineering: silicone, continued, demonstrator, modeling, europa, densities, pharmacology, tuning,
# Nearest to magazine: spassky, segmentation, masterpiece, vegas, magazines, ici, mammalian, stedman,
# Nearest to additional: ashkenazim, completion, pane, holocene, swordsmith, eg, tyler, indicate,
# Nearest to ice: user, leukemia, lydon, exterminating, downer, tab, volleyball, encouraging,
# Nearest to writers: poets, novelists, vampyre, essayists, pazzi, fiction, americans, dilution,
# Nearest to five: six, zero, one, four, two, seven, three, eight,c/batch
# Nearest to united: metre, kingdom, luce, subtitled, toured, thionyl, states, factual,
# Nearest to known: ibf, tang, timescale, istat, carom, bu, mars, algorism,
# Nearest to up: disenchanted, ewart, dagome, obstacle, shinai, burgers, mcclintock, antiprotons,
# Nearest to but: risky, because, tver, their, applying, the, collectively, sums,
# Nearest to were: now, until, them, datagrams, magazines, pistols, escorts, massive,
# Nearest to history: pride, shown, article, goa, notoc, ethnomusicology, description, boardgamegeek,
# Nearest to other: are, from, predominantly, oresund, darwinism, cultivating, smo, aryan,
# Nearest to police: joliet, lonesome, condiments, out, hanjour, constabulary, macquarie, guard,
# Nearest to joseph: polymath, referred, formless, facets, yangon, mej, kircher, theologies,
# Nearest to alternative: cksburg, merck, polypeptides, buzan, alliterative, milarepa, craft, countdown,
# Nearest to engineering: continued, silicone, demonstrator, modeling, europa, densities, tuning, pharmacology,
# Nearest to magazine: masterpiece, magazines, segmentation, spassky, vegas, mammalian, stedman, ici,
# Nearest to additional: pane, completion, ashkenazim, tyler, swordsmith, holocene, searle, eg,
# Nearest to ice: user, leukemia, volleyball, exterminating, lydon, olympics, corvo, tab,
# Nearest to writers: poets, novelists, vampyre, essayists, pazzi, americans, fiction, dilution,
# Nearest to five: six, zero, one, four, two, seven, eight, three,c/batch
# Nearest to united: kingdom, luce, metre, subtitled, states, factual, toured, fades,
# Nearest to known: istat, ibf, carom, ontario, algorism, petal, timescale, miller,
# Nearest to up: disenchanted, dagome, shinai, ewart, burgers, obstacle, ssi, mcclintock,
# Nearest to but: because, risky, the, their, collectively, sums, tver, enlist,
# Nearest to were: datagrams, now, until, them, pistols, magazines, attempted, minicomputer,
# Nearest to history: article, shown, pride, notoc, goa, ethnomusicology, description, detailed,
# Nearest to other: are, from, darwinism, oresund, smo, predominantly, actually, and,
# Nearest to police: joliet, constabulary, condiments, lonesome, out, hanjour, visigothic, rcito,
# Nearest to joseph: polymath, tanach, yangon, facets, kircher, mej, homily, referred,
# Nearest to alternative: cksburg, polypeptides, merck, buzan, alliterative, milarepa, countdown, satrap,
# Nearest to engineering: silicone, modeling, europa, continued, demonstrator, densities, pharmacology, facilities,
# Nearest to magazine: magazines, masterpiece, mammalian, segmentation, spassky, methodological, vegas, busters,
# Nearest to additional: pane, searle, holocene, completion, tyler, swordsmith, eg, ashkenazim,
# Nearest to ice: user, leukemia, volleyball, exterminating, tab, lydon, corvo, liquid,
# Nearest to writers: poets, novelists, vampyre, essayists, fiction, americans, pazzi, actors,
# Nearest to five: zero, six, one, two, four, eight, seven, three,c/batch
# Nearest to united: kingdom, metre, luce, subtitled, states, toured, thionyl, certiorari,
# Nearest to known: ibf, algorism, timescale, istat, bu, petal, miller, been,
# Nearest to up: disenchanted, shinai, burgers, ewart, mcclintock, ssi, obstacle, dagome,
# Nearest to but: the, their, tver, because, risky, to, enlist, gainsborough,
# Nearest to were: escorts, until, now, attempted, pistols, four, them, apennines,
# Nearest to history: article, shown, notoc, ethnomusicology, detailed, pride, goa, description,
# Nearest to other: are, from, darwinism, predominantly, smo, oresund, or, grand,
# Nearest to police: joliet, constabulary, out, lonesome, hanjour, condiments, guard, rcito,
# Nearest to joseph: polymath, referred, yangon, rgya, facets, anabolism, kircher, tanach,
# Nearest to alternative: cksburg, polypeptides, buzan, merck, alliterative, fontvieille, divert, craft,
# Nearest to engineering: silicone, demonstrator, europa, modeling, continued, densities, pharmacology, tuning,
# Nearest to magazine: magazines, mammalian, spassky, methodological, masterpiece, segmentation, erd, busters,
# Nearest to additional: holocene, searle, pane, completion, swordsmith, tyler, ashkenazim, eg,
# Nearest to ice: leukemia, user, tab, volleyball, exterminating, corvo, lydon, estimator,
# Nearest to writers: poets, novelists, vampyre, essayists, fiction, americans, pazzi, dilution,
# Nearest to five: zero, six, one, four, two, seven, eight, three,c/batch
# Nearest to united: kingdom, metre, luce, states, subtitled, toured, certiorari, thionyl,
# Nearest to known: ibf, been, bu, timescale, istat, algorism, miller, carom,
# Nearest to up: disenchanted, burgers, obstacle, ewart, dagome, mcclintock, ssi, incidences,
# Nearest to but: because, tver, their, to, the, risky, wind, enlist,
# Nearest to were: escorts, attempted, them, until, had, now, including, four,
# Nearest to history: article, notoc, ethnomusicology, shown, goa, detailed, pride, peoples,
# Nearest to other: are, kontor, from, predominantly, oresund, or, such, smo,
# Nearest to police: constabulary, joliet, rcito, lonesome, guard, visigothic, out, hanjour,
# Nearest to joseph: polymath, referred, formless, homily, kircher, anabolism, ladislaus, tanach,
# Nearest to alternative: cksburg, polypeptides, buzan, merck, alliterative, divert, fontvieille, milarepa,
# Nearest to engineering: silicone, demonstrator, densities, modeling, europa, continued, tuning, pharmacology,
# Nearest to magazine: magazines, masterpiece, mammalian, spassky, methodological, busters, stedman, segmentation,
# Nearest to additional: ashkenazim, tyler, holocene, pane, searle, completion, swordsmith, addition,
# Nearest to ice: user, leukemia, volleyball, exterminating, tab, lydon, olympics, liquid,
# Nearest to writers: poets, novelists, essayists, vampyre, americans, fiction, natives, actors,
# Nearest to five: six, zero, one, two, four, seven, eight, three,c/batch
# Nearest to united: metre, kingdom, states, luce, thionyl, subtitled, toured, choate,
# Nearest to known: ibf, can, miller, carom, bu, istat, tang, stills,
# Nearest to up: disenchanted, burgers, obstacle, draconic, ewart, mcclintock, emmerdale, gestation,
# Nearest to but: their, tver, to, risky, because, the, sums, comedy,
# Nearest to were: them, until, escorts, now, apennines, including, attempted, had,
# Nearest to history: ethnomusicology, article, notoc, pride, shown, peoples, goa, detailed,
# Nearest to other: are, including, oresund, such, darwinism, predominantly, smo, from,
# Nearest to police: joliet, hanjour, constabulary, guard, visigothic, lonesome, neighbour, condiments,
# Nearest to joseph: polymath, kircher, referred, formless, rgya, anabolism, homily, facets,
# Nearest to alternative: cksburg, polypeptides, buzan, alliterative, merck, aeolic, fontvieille, divert,
# Nearest to engineering: silicone, demonstrator, continued, densities, modeling, europa, tuning, somewhat,
# Nearest to magazine: magazines, masterpiece, spassky, mammalian, stedman, segmentation, busters, annan,
# Nearest to additional: holocene, pane, ashkenazim, completion, swordsmith, addition, searle, tyler,
# Nearest to ice: user, leukemia, volleyball, exterminating, tab, lydon, olympics, corvo,
# Nearest to writers: poets, novelists, essayists, vampyre, fiction, americans, natives, dilution,
# Nearest to five: zero, six, two, one, four, three, seven, eight,c/batch
# Nearest to united: kingdom, states, metre, luce, thionyl, subtitled, certiorari, fades,
# Nearest to known: ibf, been, can, miller, istat, petal, carom, stills,
# Nearest to up: disenchanted, obstacle, draconic, ewart, mcclintock, burgers, emmerdale, dagome,
# Nearest to but: to, tver, their, the, because, risky, they, that,
# Nearest to were: them, had, attempted, now, including, until, escorts, interstates,
# Nearest to history: article, notoc, shown, pride, ethnomusicology, peoples, detailed, goa,
# Nearest to other: are, oresund, such, from, including, predominantly, and, or,
# Nearest to police: neighbour, hanjour, constabulary, rcito, visigothic, joliet, condiments, guard,
# Nearest to joseph: polymath, kircher, referred, anabolism, formless, homily, latter, balked,
# Nearest to alternative: cksburg, buzan, polypeptides, merck, alliterative, jasmuheen, divert, milarepa,
# Nearest to engineering: silicone, demonstrator, modeling, densities, continued, europa, pharmacology, tuning,
# Nearest to magazine: magazines, masterpiece, spassky, mammalian, busters, stedman, segmentation, methodological,
# Nearest to additional: searle, holocene, pane, ashkenazim, completion, swordsmith, eg, tyler,
# Nearest to ice: user, leukemia, volleyball, exterminating, tab, lydon, olympics, liquid,
# Nearest to writers: poets, novelists, vampyre, essayists, fiction, americans, dilution, natives,
# Nearest to five: zero, six, one, two, four, three, eight, seven,c/batch
# Nearest to united: kingdom, states, luce, metre, thionyl, subtitled, fades, choate,
# Nearest to known: been, ibf, algorism, istat, miller, can, stills, carom,
# Nearest to up: disenchanted, obstacle, ewart, burgers, splintering, emmerdale, snake, draconic,
# Nearest to but: their, the, to, tver, of, because, and, risky,
# Nearest to were: them, now, attempted, until, magazines, escorts, had, including,
# Nearest to history: notoc, shown, article, ethnomusicology, references, pride, peoples, description,
# Nearest to other: are, such, from, including, oresund, or, of, in,
# Nearest to police: hanjour, constabulary, neighbour, joliet, guard, eradication, condiments, rcito,
# Nearest to joseph: anabolism, polymath, kircher, rgya, referred, yangon, balked, homily,
# Nearest to alternative: cksburg, buzan, polypeptides, merck, divert, alliterative, milarepa, fontvieille,
# Nearest to engineering: silicone, demonstrator, tuning, densities, continued, europa, training, sciences,
# Nearest to magazine: magazines, mammalian, masterpiece, spassky, busters, stedman, methodological, prep,
# Nearest to additional: searle, holocene, ashkenazim, completion, swordsmith, pane, eg, tyler,
# Nearest to ice: user, leukemia, volleyball, exterminating, tab, liquid, lydon, olympics,
# Nearest to writers: poets, novelists, essayists, vampyre, fiction, natives, literary, dilution,
# Nearest to five: zero, six, one, two, four, three, seven, eight,c/batch
# Nearest to united: kingdom, states, luce, metre, thionyl, fades, subtitled, toured,
# Nearest to known: been, the, ibf, istat, algorism, timescale, miller, stills,
# Nearest to up: disenchanted, obstacle, very, burgers, splintering, ewart, emmerdale, voids,
# Nearest to but: the, to, of, their, and, because, they, tver,
# Nearest to were: had, until, them, including, attempted, four, now, two,
# Nearest to history: notoc, article, shown, ethnomusicology, peoples, goa, references, historical,
# Nearest to other: are, of, and, from, such, in, including, or,
# Nearest to police: constabulary, extrajudicial, hanjour, guard, condiments, rcito, visigothic, joliet,
# Nearest to joseph: anabolism, kircher, yangon, referred, homily, rgya, polymath, formless,
# Nearest to alternative: cksburg, buzan, polypeptides, divert, alliterative, merck, jasmuheen, fontvieille,
# Nearest to engineering: silicone, demonstrator, tuning, densities, europa, somewhat, pharmacology, modeling,
# Nearest to magazine: magazines, spassky, mammalian, masterpiece, busters, pencil, stedman, rdx,
# Nearest to additional: searle, holocene, ashkenazim, completion, tyler, swordsmith, faris, ninth,
# Nearest to ice: user, volleyball, leukemia, exterminating, tab, liquid, lydon, encouraging,
# Nearest to writers: novelists, poets, fiction, essayists, vampyre, natives, dilution, americans,
# Nearest to five: zero, one, six, four, two, seven, three, eight,c/batch
# Nearest to united: kingdom, states, luce, metre, thionyl, nations, subtitled, fades,
# Nearest to known: been, ibf, as, the, istat, carom, are, algorism,
# Nearest to up: disenchanted, ewart, obstacle, emmerdale, burgers, very, boys, mcclintock,
# Nearest to but: the, tver, to, their, they, because, and, of,
# Nearest to were: them, had, including, until, attempted, four, now, magazines,
# Nearest to history: notoc, article, shown, peoples, pride, ethnomusicology, goa, detailed,
# Nearest to other: are, and, including, such, from, of, in, or,
# Nearest to police: guard, constabulary, hanjour, extrajudicial, archaically, rcito, out, visigothic,
# Nearest to joseph: anabolism, yangon, referred, kircher, homily, rgya, polymath, formless,
# Nearest to alternative: cksburg, buzan, polypeptides, alliterative, aeolic, jasmuheen, satrap, fontvieille,
# Nearest to engineering: silicone, demonstrator, tuning, somewhat, densities, europa, pharmacology, modeling,
# Nearest to magazine: magazines, masterpiece, mammalian, spassky, busters, pencil, rdx, segmentation,
# Nearest to additional: searle, holocene, ashkenazim, swordsmith, completion, tyler, eg, pane,
# Nearest to ice: user, leukemia, volleyball, exterminating, lydon, criminology, encouraging, liquid,
# Nearest to writers: novelists, poets, essayists, fiction, vampyre, natives, americans, dilution,
# Nearest to five: six, one, zero, four, two, seven, eight, three,c/batch
# Nearest to united: states, kingdom, luce, metre, subtitled, thionyl, fades, nations,
# Nearest to known: ibf, been, as, carom, miller, istat, bu, also,
# Nearest to up: disenchanted, obstacle, ewart, draconic, mcclintock, splintering, of, ssi,
# Nearest to but: to, the, tver, they, because, and, their, of,
# Nearest to were: them, had, until, including, now, attempted, they, evident,
# Nearest to history: shown, article, notoc, pride, peoples, detailed, boardgamegeek, historical,
# Nearest to other: are, such, including, or, from, as, and, of,
# Nearest to police: constabulary, guard, hanjour, extrajudicial, rcito, archaically, visigothic, bayard,
# Nearest to joseph: anabolism, yangon, referred, polymath, kircher, homily, formless, bellied,
# Nearest to alternative: cksburg, buzan, polypeptides, jasmuheen, alliterative, aeolic, complementary, craft,
# Nearest to engineering: silicone, tuning, demonstrator, europa, densities, continued, modeling, somewhat,
# ...
# Nearest to engineering: silicone, tuning, demonstrator, somewhat, europa, modeling, pharmacology, densities,
# Nearest to magazine: magazines, pencil, mammalian, masterpiece, rdx, busters, spassky, interview,
# Nearest to additional: searle, holocene, swordsmith, pane, ashkenazim, eg, slits, tyler,
# Nearest to ice: user, volleyball, leukemia, exterminating, tab, criminology, liquid, lydon,
# Nearest to writers: novelists, poets, fiction, essayists, vampyre, natives, dilution, pazzi,
# Nearest to five: one, zero, six, four, two, seven, eight, three,c/batch
# Nearest to united: states, kingdom, luce, subtitled, nations, choate, fades, thionyl,
# Nearest to known: been, as, are, ibf, algorism, istat, carom, facetious,
# Nearest to up: disenchanted, obstacle, together, very, splintering, ewart, krakatau, incidences,
# Nearest to but: they, to, the, that, because, their, and, of,
# Nearest to were: had, until, them, now, they, aikman, including, attempted,
# Nearest to history: article, shown, notoc, peoples, references, detailed, ethnomusicology, pride,
# Nearest to other: are, such, from, or, including, as, of, and,
# Nearest to police: guard, constabulary, hanjour, neighbour, purported, eradication, extrajudicial, businesswoman,
# Nearest to joseph: yangon, anabolism, polymath, referred, homily, kircher, rgya, mej,
# Nearest to alternative: cksburg, buzan, aeolic, polypeptides, alliterative, patti, divert, satrap,
# Nearest to engineering: silicone, tuning, demonstrator, europa, somewhat, pharmacology, densities, modeling,
# Nearest to magazine: magazines, masterpiece, pencil, ifex, mammalian, busters, repatriation, spassky,
# Nearest to additional: searle, holocene, ashkenazim, swordsmith, tyler, eg, pane, bhutan,
# Nearest to ice: user, leukemia, volleyball, exterminating, miracle, antarctica, criminology, vx,
# Nearest to writers: novelists, poets, natives, fiction, essayists, vampyre, pazzi, dilution,
# Nearest to five: one, zero, six, four, two, seven, three, eight,c/batch
# Nearest to united: states, kingdom, luce, fades, thionyl, nations, choate, metre,
# Nearest to known: been, as, ibf, are, carom, born, istat, algorism,
# Nearest to up: disenchanted, very, together, splintering, obstacle, ewart, shimla, incidences,
# Nearest to but: to, the, they, their, and, tver, because, that,
# Nearest to were: them, had, including, they, until, attempted, evident, their,
# Nearest to history: article, shown, detailed, notoc, peoples, pride, boardgamegeek, ethnomusicology,
# Nearest to other: are, such, including, or, from, as, the, and,
# Nearest to police: guard, hanjour, purported, constabulary, neighbour, eradication, bayard, extrajudicial,
# Nearest to joseph: polymath, anabolism, yangon, homily, kircher, martha, referred, rgya,
# Nearest to alternative: cksburg, buzan, aeolic, polypeptides, alliterative, sizeof, divert, satrap,
# Nearest to engineering: silicone, demonstrator, tuning, pharmacology, somewhat, modeling, europa, constructed,
# Nearest to magazine: magazines, pencil, mammalian, ifex, busters, rdx, spassky, masterpiece,
# Nearest to additional: searle, swordsmith, holocene, ashkenazim, tyler, pane, bhutan, slits,
# Nearest to ice: user, leukemia, volleyball, exterminating, antarctica, devastates, miracle, criminology,
# Nearest to writers: novelists, poets, natives, fiction, essayists, vampyre, americans, cannabis,
# Nearest to five: one, six, four, zero, two, three, seven, eight,c/batch
# Nearest to united: states, kingdom, luce, fades, thionyl, nations, metre, choate,
# Nearest to known: been, as, are, ibf, carom, a, istat, also,
# Nearest to up: disenchanted, of, very, draconic, together, obstacle, splintering, a,
# Nearest to but: the, to, they, and, tver, their, of, that,
# Nearest to were: them, had, they, four, including, two, until, aikman,
# Nearest to history: shown, article, detailed, notoc, peoples, references, historical, pride,
# Nearest to other: are, such, of, from, including, or, as, oresund,
# Nearest to police: guard, hanjour, constabulary, neighbour, purported, eradication, extrajudicial, archaically,
# Nearest to joseph: anabolism, yangon, polymath, homily, cadres, referred, formless, alumina,
# Nearest to alternative: cksburg, buzan, aeolic, alliterative, polypeptides, jasmuheen, complementary, craft,
# Nearest to engineering: silicone, tuning, demonstrator, modeling, pharmacology, europa, banking, constructed,
# Nearest to magazine: magazines, pencil, busters, prep, ifex, mammalian, rdx, repatriation,
# Nearest to additional: searle, holocene, swordsmith, ashkenazim, bhutan, tyler, pane, relayed,
# Nearest to ice: user, volleyball, leukemia, exterminating, antarctica, criminology, miracle, estimator,
# Nearest to writers: novelists, poets, natives, fiction, vampyre, essayists, megillat, cannabis,
# Nearest to five: one, zero, six, four, two, three, seven, eight,c/batch
# Nearest to united: kingdom, states, luce, fades, nations, subtitled, thionyl, donate,
# Nearest to known: been, as, a, are, most, ibf, carom, istat,
# Nearest to up: disenchanted, very, together, splintering, draconic, ewart, obstacle, connecting,
# Nearest to but: the, to, tver, they, and, their, sums, of,
# Nearest to were: had, them, four, they, two, attempted, until, three,
# Nearest to history: shown, the, article, references, notoc, peoples, detailed, ethnomusicology,
# Nearest to other: are, such, from, or, including, as, of, the,
# Nearest to police: guard, hanjour, constabulary, neighbour, purported, eradication, archaically, rcito,
# Nearest to joseph: anabolism, yangon, homily, cadres, alumina, kircher, canard, mej,
# Nearest to alternative: cksburg, aeolic, buzan, polypeptides, alliterative, jasmuheen, divert, patti,
# Nearest to engineering: silicone, tuning, pharmacology, demonstrator, modeling, facilities, europa, engineers,
# Nearest to magazine: magazines, pencil, rdx, mammalian, busters, prep, ifex, masterpiece,
# Nearest to additional: searle, holocene, swordsmith, ashkenazim, tyler, pane, bhutan, lightness,
# Nearest to ice: user, volleyball, leukemia, exterminating, antarctica, criminology, encouraging, devastates,
# Nearest to writers: novelists, poets, essayists, vampyre, fiction, natives, megillat, cannabis,
# Nearest to five: zero, one, six, four, two, three, seven, eight,c/batch
# Nearest to united: states, kingdom, nations, thionyl, luce, fades, subtitled, us,
# Nearest to known: been, as, are, the, most, also, ibf, in,
# Nearest to up: disenchanted, very, splintering, together, obstacle, draconic, ewart, shinai,
# Nearest to but: the, and, to, of, they, their, that, tver,
# Nearest to were: had, them, they, attempted, including, until, four, their,
# Nearest to history: shown, peoples, article, detailed, the, historical, notoc, references,
# Nearest to other: are, including, such, from, and, the, in, or,
# Nearest to police: guard, constabulary, rcito, neighbour, hanjour, purported, archaically, extrajudicial,
# Nearest to joseph: yangon, anabolism, cadres, polymath, homily, alumina, untranslated, chest,
# Nearest to alternative: cksburg, buzan, aeolic, alliterative, divert, polypeptides, jasmuheen, patti,
# Nearest to engineering: silicone, tuning, demonstrator, engineers, constructed, europa, pharmacology, modeling,
# Nearest to magazine: magazines, pencil, ifex, mammalian, rdx, prep, hugo, interview,
# Nearest to additional: searle, holocene, ashkenazim, swordsmith, tyler, lightness, relayed, bhutan,
# Nearest to ice: volleyball, user, leukemia, antarctica, exterminating, meltwater, devastates, encouraging,
# Nearest to writers: novelists, poets, fiction, vampyre, cannabis, natives, essayists, megillat,
# Nearest to five: zero, one, six, four, two, three, seven, eight,c/batch
# Nearest to united: states, kingdom, nations, us, thionyl, luce, saber, subtitled,
# Nearest to known: been, as, are, ibf, also, istat, a, most,
# Nearest to up: disenchanted, together, very, ewart, of, draconic, obstacle, burgers,
# Nearest to but: the, and, to, that, they, their, of, tver,
# Nearest to were: had, them, including, until, their, they, attempted, thousands,
# Nearest to history: article, shown, peoples, detailed, notoc, in, ethnomusicology, references,
# Nearest to other: are, such, including, or, the, as, from, in,
# Nearest to police: guard, neighbour, constabulary, rcito, hanjour, purported, conducted, extrajudicial,
# Nearest to joseph: anabolism, yangon, cadres, untranslated, polymath, alumina, referred, misunderstanding,
# Nearest to alternative: cksburg, aeolic, buzan, alliterative, satrap, divert, polypeptides, jasmuheen,
# Nearest to engineering: silicone, tuning, demonstrator, europa, pharmacology, engineers, banking, somewhat,
# Nearest to magazine: magazines, pencil, mammalian, ifex, prep, rdx, spassky, interview,
# Nearest to additional: searle, holocene, ashkenazim, bhutan, tyler, swordsmith, purpose, lightness,
# Nearest to ice: volleyball, user, leukemia, exterminating, criminology, encouraging, antarctica, miracle,
# Nearest to writers: novelists, poets, natives, vampyre, essayists, megillat, births, cannabis,
# Nearest to five: one, six, zero, four, two, three, seven, eight,ec/batch
# Nearest to united: states, kingdom, nations, luce, subtitled, fades, thionyl, us,
# Nearest to known: been, as, a, are, the, in, also, most,
# Nearest to up: disenchanted, draconic, very, together, splintering, obstacle, of, a,
# Nearest to but: the, to, and, tver, they, of, their, that,
# Nearest to were: had, them, their, they, including, until, evident, mustered,
# Nearest to history: article, detailed, shown, peoples, ethnomusicology, notoc, references, the,
# Nearest to other: are, such, including, the, or, from, a, as,
# Nearest to police: guard, constabulary, neighbour, hanjour, archaically, rcito, conducted, purported,
# Nearest to joseph: yangon, anabolism, untranslated, cadres, polymath, alumina, referred, ladislaus,
# Nearest to alternative: cksburg, aeolic, buzan, alliterative, polypeptides, jasmuheen, complementary, penelope,
# Nearest to engineering: silicone, tuning, constructed, demonstrator, banking, modeling, engineers, europa,
# Nearest to magazine: magazines, pencil, ifex, rdx, mammalian, mackintosh, prep, alekhine,
# Nearest to additional: searle, holocene, swordsmith, bhutan, ashkenazim, lightness, launches, tyler,
# Nearest to ice: volleyball, user, antarctica, exterminating, leukemia, criminology, encouraging, meltwater,
# Nearest to writers: novelists, poets, natives, vampyre, essayists, megillat, births, fiction,
# Nearest to five: one, six, zero, two, four, three, seven, eight,ec/batch
# Nearest to united: states, kingdom, nations, subtitled, us, luce, fades, thionyl,
# Nearest to known: been, as, a, are, also, in, can, istat,
# Nearest to up: disenchanted, very, together, draconic, of, splintering, obstacle, line,
# Nearest to but: the, to, that, and, they, of, tver, sums,
# Nearest to were: had, them, they, including, their, attempted, evident, thousands,
# Nearest to history: shown, article, detailed, the, peoples, notoc, external, references,
# Nearest to other: are, such, the, of, or, including, in, as,
# Nearest to police: guard, neighbour, constabulary, archaically, rcito, hanjour, eradication, extrajudicial,
# Nearest to joseph: latter, yangon, anabolism, cadres, referred, untranslated, homily, alumina,
# Nearest to alternative: cksburg, aeolic, buzan, divert, polypeptides, alliterative, satrap, complementary,
# Nearest to engineering: silicone, engineers, tuning, demonstrator, pharmacology, sciences, constructed, europa,
# Nearest to magazine: magazines, pencil, rdx, prep, mackintosh, mammalian, ifex, busters,
# Nearest to additional: searle, holocene, lightness, bhutan, swordsmith, ashkenazim, tyler, relayed,
# Nearest to ice: volleyball, user, exterminating, antarctica, leukemia, criminology, encouraging, meltwater,
# Nearest to writers: novelists, poets, vampyre, natives, essayists, megillat, fiction, cannabis,
# Nearest to five: one, six, zero, two, four, three, eight, seven,ec/batch
# Nearest to united: states, kingdom, nations, subtitled, luce, us, fades, thionyl,
# Nearest to known: been, as, a, are, also, carom, can, istat,
# Nearest to up: disenchanted, together, very, splintering, draconic, obstacle, of, connecting,
# Nearest to but: the, to, and, that, they, sums, tver, of,
# Nearest to were: they, had, them, upwardly, including, their, thousands, four,
# Nearest to history: shown, article, the, peoples, detailed, references, ethnomusicology, notoc,
# Nearest to other: are, including, such, from, the, or, of, in,
# Nearest to police: constabulary, guard, neighbour, rcito, archaically, extrajudicial, hanjour, eradication,
# Nearest to joseph: yangon, anabolism, alumina, cadres, untranslated, referred, fosbury, canard,
# Nearest to alternative: cksburg, aeolic, buzan, alliterative, polypeptides, divert, sizeof, gaulois,
# Nearest to engineering: silicone, tuning, engineers, europa, somewhat, pharmacology, sciences, constructed,
# Nearest to magazine: magazines, pencil, prep, ifex, interview, rdx, mammalian, mackintosh,
# Nearest to additional: searle, holocene, swordsmith, lightness, tyler, relayed, nearly, ulvaeus,
# Nearest to ice: volleyball, user, exterminating, leukemia, antarctica, encouraging, criminology, devastates,
# Nearest to writers: novelists, poets, vampyre, essayists, natives, megillat, fiction, cannabis,
# Nearest to five: one, six, zero, four, two, three, seven, eight,ec/batch
# Nearest to united: states, kingdom, nations, us, thionyl, luce, subtitled, fifth,
# Nearest to known: been, as, also, a, the, are, referred, in,
# Nearest to up: disenchanted, very, together, draconic, obstacle, of, splintering, ssi,
# Nearest to but: the, to, and, they, that, tver, their, of,
# Nearest to were: had, their, including, them, four, they, upwardly, three,
# Nearest to history: article, peoples, shown, the, references, in, notoc, detailed,
# Nearest to other: are, such, the, from, including, or, some, of,
# Nearest to police: constabulary, guard, neighbour, archaically, rcito, hanjour, revolutionary, extrajudicial,
# Nearest to joseph: anabolism, yangon, cadres, alumina, untranslated, fosbury, chest, engraved,
# Nearest to alternative: cksburg, aeolic, buzan, alliterative, divert, gaulois, patti, satrap,
# Nearest to engineering: silicone, engineers, tuning, somewhat, europa, constructed, banking, pharmacology,
# Nearest to magazine: magazines, pencil, prep, mammalian, rdx, mackintosh, masterpiece, gillmor,
# Nearest to additional: searle, holocene, ashkenazim, swordsmith, nearly, tyler, bhutan, month,
# Nearest to ice: volleyball, exterminating, leukemia, user, antarctica, devastates, encouraging, miracle,
# Nearest to writers: novelists, poets, essayists, natives, cannabis, vampyre, megillat, births,
# Nearest to five: one, six, zero, two, four, three, seven, eight,ec/batch
# Nearest to united: states, kingdom, nations, us, subtitled, luce, thionyl, fifth,
# Nearest to known: as, been, a, also, the, are, other, most,
# Nearest to up: disenchanted, very, together, splintering, villard, obstacle, a, hard,
# Nearest to but: the, to, tver, and, they, that, their, well,
# Nearest to were: including, had, their, thousands, them, until, upwardly, they,
# Nearest to history: article, shown, peoples, notoc, the, detailed, references, ethnomusicology,
# Nearest to other: are, including, such, the, or, and, in, from,
# Nearest to police: guard, neighbour, constabulary, archaically, hanjour, conducted, rcito, revolutionary,
# Nearest to joseph: anabolism, yangon, untranslated, alumina, referred, cadres, polymath, kircher,
# Nearest to alternative: cksburg, aeolic, alliterative, buzan, patti, gaulois, polypeptides, divert,
# Nearest to engineering: silicone, tuning, europa, engineers, banking, constructed, pharmacology, somewhat,
# Nearest to magazine: magazines, pencil, prep, alekhine, morita, masterpiece, gillmor, ifex,
# Nearest to additional: searle, holocene, ashkenazim, nearly, swordsmith, bhutan, tyler, ulvaeus,
# Nearest to ice: volleyball, leukemia, exterminating, user, antarctica, miracle, devastates, ota,
# Nearest to writers: novelists, poets, natives, vampyre, essayists, fiction, megillat, cannabis,
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.7634 0.0223 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
